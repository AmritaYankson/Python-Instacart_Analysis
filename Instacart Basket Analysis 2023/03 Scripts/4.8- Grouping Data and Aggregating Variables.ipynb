# %% [markdown]
# # Grouping Data and Aggregating Variables

# %% [markdown]
# ### Import Libraries

# %%
# import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ### Import Data

# %%
# Creating a path

# %%
path = r'/Users/amritamaniram/Desktop/Instacart Basket Analysis 2023'

# %%
# ords_prods_merge

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_derived.pkl'))

# %%
# Look for 'busiest_days' and 'busiest_period_of_day'

# %%
ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   3139998      138    prior            28                   6
# 1   1977647      138    prior            30                   6
# 2    389851      709    prior             2                   0
# 3    652770      764    prior             1                   3
# 4   1813452      764    prior             3                   4
#
#    order_hour_of_day  time_elapsed_since_last_order  add_to_cart_order  \
# 0                 11                            3.0                  5
# 1                 17                           20.0                  1
# 2                 21                            6.0                 20
# 3                 13                            NaN                 10
# 4                 17                            9.0                 11
#
#    reordered _merge    price_range_loc  busiest_day  busiest_days  \
# 0          0   both  Mid-range product      average       average
# 1          1   both  Mid-range product      average       average
# 2          0   both  Mid-range product  Busiest day  Busiest days
# 3          0   both  Mid-range product      average  Slowest days
# 4          1   both  Mid-range product   Least busy  Slowest days
#
#   busiest_period_of_day
# 0           Most orders
# 1        Average orders
# 2        Average orders
# 3           Most orders
# 4        Average orders

# %% [markdown]
# ### Aggregated mean of 'order_number' grouped by 'department_id'

# %%
# group by 'department_id' and 'order_number'

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457687
# 2     17.277920
# 3     17.179756
# 4     17.811403
# 5     15.213779
# 6     16.439806
# 7     17.225773
# 8     15.340520
# 9     15.895474
# 10    20.197148
# 11    16.170828
# 12    15.887622
# 13    16.583304
# 14    16.757377
# 15    16.165037
# 16    17.663250
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %% [markdown]
# ### How do the results for the entire dataframe differ from those of the subset?

# %% [markdown]
# There are 21 in the 'department_id' in the entire dataframe when compared to 8 in the subset.

# %% [markdown]
# ### Creating flags for loyalty customers

# %%
# Create 'max_order' column

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/9y/_7m06bz903q5c1hc2s5r6xpc0000gn/T/ipykernel_2214/1681540670.py:1: FutureWarning: The provided callable <function amax at 0x106c83ec0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
# Verify addition of new column

# %%
ords_prods_merge.head(20)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
# 15           1  Chocolate Sandwich Cookies        61             19     5.8
# 16           1  Chocolate Sandwich Cookies        61             19     5.8
# 17           1  Chocolate Sandwich Cookies        61             19     5.8
# 18           1  Chocolate Sandwich Cookies        61             19     5.8
# 19           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    3139998      138    prior            28                   6
# 1    1977647      138    prior            30                   6
# 2     389851      709    prior             2                   0
# 3     652770      764    prior             1                   3
# 4    1813452      764    prior             3                   4
# 5    1701441      777    prior            16                   1
# 6    1871483      825    prior             3                   2
# 7    1290456      910    prior            12                   3
# 8     369558     1052    prior            10                   1
# 9     589712     1052    prior            15                   1
# 10   1798115     1379    prior             1                   5
# 11    497193     1480    prior            36                   3
# 12   1727826     1480    prior            38                   4
# 13   2694698     1480    prior            39                   2
# 14   3171753     1494    prior             6                   3
# 15    186761     1494    prior             7                   2
# 16    317121     1494    prior             9                   5
# 17    200390     1540    prior             4                   2
# 18    374436     1540    prior             5                   1
# 19   2920553     1540    prior             6                   1
#
#     order_hour_of_day  time_elapsed_since_last_order  add_to_cart_order  \
# 0                  11                            3.0                  5
# 1                  17                           20.0                  1
# 2                  21                            6.0                 20
# 3                  13                            NaN                 10
# 4                  17                            9.0                 11
# 5                   7                           26.0                  7
# 6                  14                           30.0                  2
# 7                  10                           30.0                  1
# 8                  20                           19.0                  1
# 9                  12                           15.0                  2
# 10                 11                            NaN                  1
# 11                 13                            7.0                  1
# 12                 13                            7.0                  3
# 13                 12                           12.0                  4
# 14                 10                            2.0                  8
# 15                  8                            6.0                 18
# 16                  8                           10.0                 12
# 17                  0                            7.0                 10
# 18                 21                            6.0                  9
# 19                  0                           14.0                  9
#
#     reordered _merge    price_range_loc  busiest_day  busiest_days  \
# 0           0   both  Mid-range product      average       average
# 1           1   both  Mid-range product      average       average
# 2           0   both  Mid-range product  Busiest day  Busiest days
# 3           0   both  Mid-range product      average  Slowest days
# 4           1   both  Mid-range product   Least busy  Slowest days
# 5           0   both  Mid-range product      average  Busiest days
# 6           0   both  Mid-range product      average       average
# 7           0   both  Mid-range product      average  Slowest days
# 8           0   both  Mid-range product      average  Busiest days
# 9           1   both  Mid-range product      average  Busiest days
# 10          0   both  Mid-range product      average       average
# 11          0   both  Mid-range product      average  Slowest days
# 12          1   both  Mid-range product   Least busy  Slowest days
# 13          1   both  Mid-range product      average       average
# 14          0   both  Mid-range product      average  Slowest days
# 15          1   both  Mid-range product      average       average
# 16          1   both  Mid-range product      average       average
# 17          0   both  Mid-range product      average       average
# 18          1   both  Mid-range product      average  Busiest days
# 19          1   both  Mid-range product      average  Busiest days
#
#    busiest_period_of_day  max_order
# 0            Most orders         32
# 1         Average orders         32
# 2         Average orders          5
# 3            Most orders          3
# 4         Average orders          3
# 5         Average orders         26
# 6            Most orders          9
# 7            Most orders         12
# 8         Average orders         20
# 9            Most orders         20
# 10           Most orders         10
# 11           Most orders         43
# 12           Most orders         43
# 13           Most orders         43
# 14           Most orders         13
# 15        Average orders         13
# 16        Average orders         13
# 17         Fewest orders         28
# 18        Average orders         28
# 19         Fewest orders         28

# %%
# Assign loyalty flag

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check loyalty flags

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0       138  Regular customer            28
# 1       138  Regular customer            30
# 2       709      New customer             2
# 3       764      New customer             1
# 4       764      New customer             3
# 5       777  Regular customer            16
# 6       825      New customer             3
# 7       910  Regular customer            12
# 8      1052  Regular customer            10
# 9      1052  Regular customer            15
# 10     1379      New customer             1
# 11     1480    Loyal customer            36
# 12     1480    Loyal customer            38
# 13     1480    Loyal customer            39
# 14     1494  Regular customer             6
# 15     1494  Regular customer             7
# 16     1494  Regular customer             9
# 17     1540  Regular customer             4
# 18     1540  Regular customer             5
# 19     1540  Regular customer             6

# %% [markdown]
# ### Comparison of customer spending

# %%
# Min/Max of loyalty flag

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.388747  1.0  99999.0
# New customer      13.294370  1.0  99999.0
# Regular customer  12.496203  1.0  99999.0

# %% [markdown]
# Loyal customer spend the least , new customer spend the most , and regular customer falls in between. This is seen by observing the mean.

# %% [markdown]
# ### Creating flag on price mean of spender

# %%
# Create 'average_spend' column

# %%
ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# /var/folders/9y/_7m06bz903q5c1hc2s5r6xpc0000gn/T/ipykernel_2214/3179845422.py:1: FutureWarning: The provided callable <function mean at 0x106c8cc20> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['average_spend'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
# Verify addition of new column

# %%
ords_prods_merge.head(20)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
# 15           1  Chocolate Sandwich Cookies        61             19     5.8
# 16           1  Chocolate Sandwich Cookies        61             19     5.8
# 17           1  Chocolate Sandwich Cookies        61             19     5.8
# 18           1  Chocolate Sandwich Cookies        61             19     5.8
# 19           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  orders_day_of_week  ...  \
# 0    3139998      138    prior            28                   6  ...
# 1    1977647      138    prior            30                   6  ...
# 2     389851      709    prior             2                   0  ...
# 3     652770      764    prior             1                   3  ...
# 4    1813452      764    prior             3                   4  ...
# 5    1701441      777    prior            16                   1  ...
# 6    1871483      825    prior             3                   2  ...
# 7    1290456      910    prior            12                   3  ...
# 8     369558     1052    prior            10                   1  ...
# 9     589712     1052    prior            15                   1  ...
# 10   1798115     1379    prior             1                   5  ...
# 11    497193     1480    prior            36                   3  ...
# 12   1727826     1480    prior            38                   4  ...
# 13   2694698     1480    prior            39                   2  ...
# 14   3171753     1494    prior             6                   3  ...
# 15    186761     1494    prior             7                   2  ...
# 16    317121     1494    prior             9                   5  ...
# 17    200390     1540    prior             4                   2  ...
# 18    374436     1540    prior             5                   1  ...
# 19   2920553     1540    prior             6                   1  ...
#
#     add_to_cart_order  reordered  _merge    price_range_loc  busiest_day  \
# 0                   5          0    both  Mid-range product      average
# 1                   1          1    both  Mid-range product      average
# 2                  20          0    both  Mid-range product  Busiest day
# 3                  10          0    both  Mid-range product      average
# 4                  11          1    both  Mid-range product   Least busy
# 5                   7          0    both  Mid-range product      average
# 6                   2          0    both  Mid-range product      average
# 7                   1          0    both  Mid-range product      average
# 8                   1          0    both  Mid-range product      average
# 9                   2          1    both  Mid-range product      average
# 10                  1          0    both  Mid-range product      average
# 11                  1          0    both  Mid-range product      average
# 12                  3          1    both  Mid-range product   Least busy
# 13                  4          1    both  Mid-range product      average
# 14                  8          0    both  Mid-range product      average
# 15                 18          1    both  Mid-range product      average
# 16                 12          1    both  Mid-range product      average
# 17                 10          0    both  Mid-range product      average
# 18                  9          1    both  Mid-range product      average
# 19                  9          1    both  Mid-range product      average
#
#     busiest_days busiest_period_of_day max_order      loyalty_flag  \
# 0        average           Most orders        32  Regular customer
# 1        average        Average orders        32  Regular customer
# 2   Busiest days        Average orders         5      New customer
# 3   Slowest days           Most orders         3      New customer
# 4   Slowest days        Average orders         3      New customer
# 5   Busiest days        Average orders        26  Regular customer
# 6        average           Most orders         9      New customer
# 7   Slowest days           Most orders        12  Regular customer
# 8   Busiest days        Average orders        20  Regular customer
# 9   Busiest days           Most orders        20  Regular customer
# 10       average           Most orders        10      New customer
# 11  Slowest days           Most orders        43    Loyal customer
# 12  Slowest days           Most orders        43    Loyal customer
# 13       average           Most orders        43    Loyal customer
# 14  Slowest days           Most orders        13  Regular customer
# 15       average        Average orders        13  Regular customer
# 16       average        Average orders        13  Regular customer
# 17       average         Fewest orders        28  Regular customer
# 18  Busiest days        Average orders        28  Regular customer
# 19  Busiest days         Fewest orders        28  Regular customer
#
#     average_spend
# 0        6.935811
# 1        6.935811
# 2        7.930208
# 3        4.972414
# 4        4.972414
# 5        6.935398
# 6        5.957576
# 7        6.680000
# 8        7.162500
# 9        7.162500
# 10       5.813636
# 11       5.139394
# 12       5.139394
# 13       5.139394
# 14       6.803797
# 15       6.803797
# 16       6.803797
# 17       6.607122
# 18       6.607122
# 19       6.607122
#
# [20 rows x 22 columns]

# %%
# Creating flag for lowest and highest spender

# %%
ords_prods_merge.loc[ords_prods_merge['average_spend']<10,'spender_flag']='Low_spender'

# %%
ords_prods_merge.loc[ords_prods_merge['average_spend']>= 10, 'spender_flag'] = 'High_spender'

# %%
# Check Spender Flags

# %%
ords_prods_merge['spender_flag'].value_counts(dropna = False)
# Out:
# spender_flag
# Low_spender     31798751
# High_spender      635461
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'average_spend', 'spender_flag', 'prices']].head(60)
# Out:
#     user_id  average_spend spender_flag  prices
# 0       138       6.935811  Low_spender     5.8
# 1       138       6.935811  Low_spender     5.8
# 2       709       7.930208  Low_spender     5.8
# 3       764       4.972414  Low_spender     5.8
# 4       764       4.972414  Low_spender     5.8
# 5       777       6.935398  Low_spender     5.8
# 6       825       5.957576  Low_spender     5.8
# 7       910       6.680000  Low_spender     5.8
# 8      1052       7.162500  Low_spender     5.8
# 9      1052       7.162500  Low_spender     5.8
# 10     1379       5.813636  Low_spender     5.8
# 11     1480       5.139394  Low_spender     5.8
# 12     1480       5.139394  Low_spender     5.8
# 13     1480       5.139394  Low_spender     5.8
# 14     1494       6.803797  Low_spender     5.8
# 15     1494       6.803797  Low_spender     5.8
# 16     1494       6.803797  Low_spender     5.8
# 17     1540       6.607122  Low_spender     5.8
# 18     1540       6.607122  Low_spender     5.8
# 19     1540       6.607122  Low_spender     5.8
# 20     1540       6.607122  Low_spender     5.8
# 21     1540       6.607122  Low_spender     5.8
# 22     1540       6.607122  Low_spender     5.8
# 23     1540       6.607122  Low_spender     5.8
# 24     1540       6.607122  Low_spender     5.8
# 25     1540       6.607122  Low_spender     5.8
# 26     1540       6.607122  Low_spender     5.8
# 27     1540       6.607122  Low_spender     5.8
# 28     1540       6.607122  Low_spender     5.8
# 29     1540       6.607122  Low_spender     5.8
# 30     1540       6.607122  Low_spender     5.8
# 31     1540       6.607122  Low_spender     5.8
# 32     1540       6.607122  Low_spender     5.8
# 33     1540       6.607122  Low_spender     5.8
# 34     1598       7.123529  Low_spender     5.8
# 35     1598       7.123529  Low_spender     5.8
# 36     1598       7.123529  Low_spender     5.8
# 37     1647       4.853521  Low_spender     5.8
# 38     1647       4.853521  Low_spender     5.8
# 39     1647       4.853521  Low_spender     5.8
# 40     1647       4.853521  Low_spender     5.8
# 41     1647       4.853521  Low_spender     5.8
# 42     2833       7.377143  Low_spender     5.8
# 43     2850       8.054153  Low_spender     5.8
# 44     2857       8.387075  Low_spender     5.8
# 45     3010       6.452800  Low_spender     5.8
# 46     3029       7.960606  Low_spender     5.8
# 47     3395       6.322222  Low_spender     5.8
# 48     3904       7.511111  Low_spender     5.8
# 49     4006       7.441100  Low_spender     5.8
# 50     4006       7.441100  Low_spender     5.8
# 51     4006       7.441100  Low_spender     5.8
# 52     4006       7.441100  Low_spender     5.8
# 53     4006       7.441100  Low_spender     5.8
# 54     4122       7.598765  Low_spender     5.8
# 55     4141       6.033333  Low_spender     5.8
# 56     4343       7.393939  Low_spender     5.8
# 57     4553       5.715789  Low_spender     5.8
# 58     4845       7.229630  Low_spender     5.8
# 59     6866       4.807143  Low_spender     5.8

# %% [markdown]
# ### Create flag for frequent users

# %%
# Create column for frequet users

# %%
ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['time_elapsed_since_last_order'].transform(np.median)
# Out:
# /var/folders/9y/_7m06bz903q5c1hc2s5r6xpc0000gn/T/ipykernel_2214/4038628058.py:1: FutureWarning: The provided callable <function median at 0x106f6eca0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['Customer_frequency'] = ords_prods_merge.groupby(['user_id'])['time_elapsed_since_last_order'].transform(np.median)

# %%
# Verify addition of new column

# %%
ords_prods_merge.head(20)
# Out:
#     product_id                product_name  aisle_id  department_id  prices  \
# 0            1  Chocolate Sandwich Cookies        61             19     5.8
# 1            1  Chocolate Sandwich Cookies        61             19     5.8
# 2            1  Chocolate Sandwich Cookies        61             19     5.8
# 3            1  Chocolate Sandwich Cookies        61             19     5.8
# 4            1  Chocolate Sandwich Cookies        61             19     5.8
# 5            1  Chocolate Sandwich Cookies        61             19     5.8
# 6            1  Chocolate Sandwich Cookies        61             19     5.8
# 7            1  Chocolate Sandwich Cookies        61             19     5.8
# 8            1  Chocolate Sandwich Cookies        61             19     5.8
# 9            1  Chocolate Sandwich Cookies        61             19     5.8
# 10           1  Chocolate Sandwich Cookies        61             19     5.8
# 11           1  Chocolate Sandwich Cookies        61             19     5.8
# 12           1  Chocolate Sandwich Cookies        61             19     5.8
# 13           1  Chocolate Sandwich Cookies        61             19     5.8
# 14           1  Chocolate Sandwich Cookies        61             19     5.8
# 15           1  Chocolate Sandwich Cookies        61             19     5.8
# 16           1  Chocolate Sandwich Cookies        61             19     5.8
# 17           1  Chocolate Sandwich Cookies        61             19     5.8
# 18           1  Chocolate Sandwich Cookies        61             19     5.8
# 19           1  Chocolate Sandwich Cookies        61             19     5.8
#
#     order_id  user_id eval_set  order_number  orders_day_of_week  ...  _merge  \
# 0    3139998      138    prior            28                   6  ...    both
# 1    1977647      138    prior            30                   6  ...    both
# 2     389851      709    prior             2                   0  ...    both
# 3     652770      764    prior             1                   3  ...    both
# 4    1813452      764    prior             3                   4  ...    both
# 5    1701441      777    prior            16                   1  ...    both
# 6    1871483      825    prior             3                   2  ...    both
# 7    1290456      910    prior            12                   3  ...    both
# 8     369558     1052    prior            10                   1  ...    both
# 9     589712     1052    prior            15                   1  ...    both
# 10   1798115     1379    prior             1                   5  ...    both
# 11    497193     1480    prior            36                   3  ...    both
# 12   1727826     1480    prior            38                   4  ...    both
# 13   2694698     1480    prior            39                   2  ...    both
# 14   3171753     1494    prior             6                   3  ...    both
# 15    186761     1494    prior             7                   2  ...    both
# 16    317121     1494    prior             9                   5  ...    both
# 17    200390     1540    prior             4                   2  ...    both
# 18    374436     1540    prior             5                   1  ...    both
# 19   2920553     1540    prior             6                   1  ...    both
#
#       price_range_loc  busiest_day  busiest_days busiest_period_of_day  \
# 0   Mid-range product      average       average           Most orders
# 1   Mid-range product      average       average        Average orders
# 2   Mid-range product  Busiest day  Busiest days        Average orders
# 3   Mid-range product      average  Slowest days           Most orders
# 4   Mid-range product   Least busy  Slowest days        Average orders
# 5   Mid-range product      average  Busiest days        Average orders
# 6   Mid-range product      average       average           Most orders
# 7   Mid-range product      average  Slowest days           Most orders
# 8   Mid-range product      average  Busiest days        Average orders
# 9   Mid-range product      average  Busiest days           Most orders
# 10  Mid-range product      average       average           Most orders
# 11  Mid-range product      average  Slowest days           Most orders
# 12  Mid-range product   Least busy  Slowest days           Most orders
# 13  Mid-range product      average       average           Most orders
# 14  Mid-range product      average  Slowest days           Most orders
# 15  Mid-range product      average       average        Average orders
# 16  Mid-range product      average       average        Average orders
# 17  Mid-range product      average       average         Fewest orders
# 18  Mid-range product      average  Busiest days        Average orders
# 19  Mid-range product      average  Busiest days         Fewest orders
#
#    max_order      loyalty_flag average_spend spender_flag  Customer_frequency
# 0         32  Regular customer      6.935811  Low_spender                 8.0
# 1         32  Regular customer      6.935811  Low_spender                 8.0
# 2          5      New customer      7.930208  Low_spender                 8.0
# 3          3      New customer      4.972414  Low_spender                 9.0
# 4          3      New customer      4.972414  Low_spender                 9.0
# 5         26  Regular customer      6.935398  Low_spender                11.0
# 6          9      New customer      5.957576  Low_spender                20.0
# 7         12  Regular customer      6.680000  Low_spender                 6.0
# 8         20  Regular customer      7.162500  Low_spender                10.0
# 9         20  Regular customer      7.162500  Low_spender                10.0
# 10        10      New customer      5.813636  Low_spender                20.0
# 11        43    Loyal customer      5.139394  Low_spender                 7.0
# 12        43    Loyal customer      5.139394  Low_spender                 7.0
# 13        43    Loyal customer      5.139394  Low_spender                 7.0
# 14        13  Regular customer      6.803797  Low_spender                 7.0
# 15        13  Regular customer      6.803797  Low_spender                 7.0
# 16        13  Regular customer      6.803797  Low_spender                 7.0
# 17        28  Regular customer      6.607122  Low_spender                 7.0
# 18        28  Regular customer      6.607122  Low_spender                 7.0
# 19        28  Regular customer      6.607122  Low_spender                 7.0
#
# [20 rows x 24 columns]

# %%
# Create flag on order frequency

# %%
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] > 20, 'frequency_flag'] = 'Non_frequent_customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['Customer_frequency']>10) & (ords_prods_merge['Customer_frequency']<=20),
                     'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['Customer_frequency'] <= 10, 'frequency_flag'] = 'Frequent Customer'

# %%
# Check frequency flags

# %%
ords_prods_merge['frequency_flag'].value_counts(dropna = False)
# Out:
# frequency_flag
# Frequent Customer        21577409
# Regular customer          7217134
# Non_frequent_customer     3639669
# Name: count, dtype: int64

# %%
#Checking for columns

# %%
ords_prods_merge[['user_id', 'Customer_frequency', 'frequency_flag']].head(60)
# Out:
#     user_id  Customer_frequency         frequency_flag
# 0       138                 8.0      Frequent Customer
# 1       138                 8.0      Frequent Customer
# 2       709                 8.0      Frequent Customer
# 3       764                 9.0      Frequent Customer
# 4       764                 9.0      Frequent Customer
# 5       777                11.0       Regular customer
# 6       825                20.0       Regular customer
# 7       910                 6.0      Frequent Customer
# 8      1052                10.0      Frequent Customer
# 9      1052                10.0      Frequent Customer
# 10     1379                20.0       Regular customer
# 11     1480                 7.0      Frequent Customer
# 12     1480                 7.0      Frequent Customer
# 13     1480                 7.0      Frequent Customer
# 14     1494                 7.0      Frequent Customer
# 15     1494                 7.0      Frequent Customer
# 16     1494                 7.0      Frequent Customer
# 17     1540                 7.0      Frequent Customer
# 18     1540                 7.0      Frequent Customer
# 19     1540                 7.0      Frequent Customer
# 20     1540                 7.0      Frequent Customer
# 21     1540                 7.0      Frequent Customer
# 22     1540                 7.0      Frequent Customer
# 23     1540                 7.0      Frequent Customer
# 24     1540                 7.0      Frequent Customer
# 25     1540                 7.0      Frequent Customer
# 26     1540                 7.0      Frequent Customer
# 27     1540                 7.0      Frequent Customer
# 28     1540                 7.0      Frequent Customer
# 29     1540                 7.0      Frequent Customer
# 30     1540                 7.0      Frequent Customer
# 31     1540                 7.0      Frequent Customer
# 32     1540                 7.0      Frequent Customer
# 33     1540                 7.0      Frequent Customer
# 34     1598                 2.0      Frequent Customer
# 35     1598                 2.0      Frequent Customer
# 36     1598                 2.0      Frequent Customer
# 37     1647                25.0  Non_frequent_customer
# 38     1647                25.0  Non_frequent_customer
# 39     1647                25.0  Non_frequent_customer
# 40     1647                25.0  Non_frequent_customer
# 41     1647                25.0  Non_frequent_customer
# 42     2833                13.0       Regular customer
# 43     2850                 7.0      Frequent Customer
# 44     2857                11.0       Regular customer
# 45     3010                 7.0      Frequent Customer
# 46     3029                28.0  Non_frequent_customer
# 47     3395                18.0       Regular customer
# 48     3904                21.0  Non_frequent_customer
# 49     4006                 7.0      Frequent Customer
# 50     4006                 7.0      Frequent Customer
# 51     4006                 7.0      Frequent Customer
# 52     4006                 7.0      Frequent Customer
# 53     4006                 7.0      Frequent Customer
# 54     4122                 7.0      Frequent Customer
# 55     4141                30.0  Non_frequent_customer
# 56     4343                30.0  Non_frequent_customer
# 57     4553                30.0  Non_frequent_customer
# 58     4845                20.0       Regular customer
# 59     6866                30.0  Non_frequent_customer

# %% [markdown]
# ### Export file

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'aggregated_ords_prods_merge.pkl'))
